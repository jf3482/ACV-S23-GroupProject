# %% [markdown]
# # Computing quantitative features for all data.
# 1) Linking to drive
#
# 2) Initialization
#
# 3) Computing results

# %% [markdown]
# ## Import and linking to drive

# %%
## Run once to link to google drive using GCP
#!sudo apt-get install google-drive-ocamlfuse
#!sudo add-apt-repository ppa:alessandro-strada/ppa
#!sudo apt-get update
#!sudo apt-get install google-drive-ocamlfuse

# %%
# !google-drive-ocamlfuse -headless -id=553698332080-4ilebkr6tajj9d4on76a6sfjilo8dbob.apps.googleusercontent.com -secret=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

# %% [markdown]
# # Imports

# %%
# !pip install lpips
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lpips in /usr/local/lib/python3.9/dist-packages (0.1.4)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.9/dist-packages (from lpips) (1.23.1)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.9/dist-packages (from lpips) (4.65.0)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from lpips) (0.14.1)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from lpips) (1.13.1)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from lpips) (1.10.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch>=0.4.0->lpips) (11.7.99)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=0.4.0->lpips) (4.5.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.9/dist-packages (from torch>=0.4.0->lpips) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.9/dist-packages (from torch>=0.4.0->lpips) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.9/dist-packages (from torch>=0.4.0->lpips) (11.7.99)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=0.4.0->lpips) (0.40.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=0.4.0->lpips) (67.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.2.1->lpips) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.2.1->lpips) (9.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.2.1->lpips) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.2.1->lpips) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.2.1->lpips) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.2.1->lpips) (1.26.15)

# %%
import numpy as np
import os
import re
from tqdm import tqdm

import lpips
from skimage.metrics import peak_signal_noise_ratio, structural_similarity as ssim
import torch
from PIL import Image

# %% [markdown]
# # Linking up drive and initialization

# %%
#Initializing google drive to a folder
if not os.path.exists("./acv"):
  os.makedirs("./acv")

# !google-drive-ocamlfuse acv
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %%
os.chdir('/content/acv/Courses/COMS 4995-6 - Applied Computer Vision/Group Project/Codebase/AID')

# %%
'''
from google.colab import drive

drive.mount('/content/gdrive')

os.chdir('/content/gdrive/MyDrive/Courses/COMS 4995-6 - Applied Computer Vision/Group Project/Codebase/AID') 
'''
# Out:
# "\nfrom google.colab import drive\n\ndrive.mount('/content/gdrive')\n\nos.chdir('/content/gdrive/MyDrive/Courses/COMS 4995-6 - Applied Computer Vision/Group Project/Codebase/AID') \n"

# %% [markdown]
# ## Parameters

# %%
dir_hr = '../../Data/AID/AIDx1/'
dir_res = '../../Data/AID/Outputs/EDSRp4_eval8xto1x/'

# %%
csv_train = '../../Data/AID/Train1_5class/train_HR.csv'
csv_valid = '../../Data/AID/Train1_5class/valid_HR.csv'
csv_test = '../../Data/AID/Test1_2class/test_HR.csv'

# %%
dir_out = '../../Data/AID/Outputs/'

# %% [markdown]
# ## Compute quantitative features

# %% [markdown]
# ### Running first configs - 8x to 4x to 2x to 1x

# %%
test = 1
if test == 1:
  str_test = 'test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
'''
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + '2xto1x_' + str_test + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")
      '''
# Out:
# '\n# Set up the paths to the dataset directory and the output file\noutput_file = dir_res + str_test + \'_result.csv\'\n\n# Initialize the LPIPS loss function\nloss_fn_vgg = lpips.LPIPS(net=\'vgg\')\n\n# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair\nwith open(output_file, \'w\') as f:\n    for file in tqdm(list_files):\n      ind = [m.start() for m in list(re.finditer(r\'/\',file))]\n\n      img_HR = Image.open(file)\n      file2 = dir_res + \'2xto1x_\' + str_test + file[ind[-1]:]\n      img_SR = Image.open(file2)\n\n      # Convert images to tensors\n      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0\n      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0\n\n      # Compute LPIPS distance\n      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()\n\n      # Compute PSNR\n      img1_np = np.array(img_HR)\n      img2_np = np.array(img_SR)\n      psnr = peak_signal_noise_ratio(img1_np, img2_np)\n\n      # Compute SSIM\n      ssim_value = ssim(img1_np, img2_np, multichannel=True)\n\n      # Write the results to the output file\n      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")\n      '

# %%
test = 0
if test == 1:
  str_test = 'test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
'''
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + '2xto1x_' + str_test + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")
      '''
# Out:
# '\n# Set up the paths to the dataset directory and the output file\noutput_file = dir_res + str_test + \'_result.csv\'\n\n# Initialize the LPIPS loss function\nloss_fn_vgg = lpips.LPIPS(net=\'vgg\')\n\n# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair\nwith open(output_file, \'w\') as f:\n    for file in tqdm(list_files):\n      ind = [m.start() for m in list(re.finditer(r\'/\',file))]\n\n      img_HR = Image.open(file)\n      file2 = dir_res + \'2xto1x_\' + str_test + file[ind[-1]:]\n      img_SR = Image.open(file2)\n\n      # Convert images to tensors\n      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0\n      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0\n\n      # Compute LPIPS distance\n      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()\n\n      # Compute PSNR\n      img1_np = np.array(img_HR)\n      img2_np = np.array(img_SR)\n      psnr = peak_signal_noise_ratio(img1_np, img2_np)\n\n      # Compute SSIM\n      ssim_value = ssim(img1_np, img2_np, multichannel=True)\n\n      # Write the results to the output file\n      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")\n      '

# %% [markdown]
# ### Running second configs - 4x to 2x to 1x

# %%
dir_hr = '../../Data/AID/AIDx1/'
dir_res = '../../Data/AID/Outputs/EDSRp4b_eval4xto1x/'

# %%
test = 1
if test == 1:
  str_test = 'test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + '2xto1x_' + str_test + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.9/dist-packages/lpips/weights/v0.1/vgg.pth
#   0%|          | 0/710 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-09f56d610c56> in <cell line: 8>()
#      15
#      16       # Convert images to tensors
# ---> 17       img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
#      18       img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
#      19
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in __array_interface__(self)
#     694                 new["data"] = self.tobytes("raw", "L")
#     695             else:
# --> 696                 new["data"] = self.tobytes()
#     697         except Exception as e:
#     698             if not isinstance(e, (MemoryError, RecursionError)):
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     752             args = self.mode
#     753
# --> 754         self.load()
#     755
#     756         if self.width == 0 or self.height == 0:
#
# /usr/local/lib/python3.9/dist-packages/PIL/ImageFile.py in load(self)
#     286         if not self.map and not LOAD_TRUNCATED_IMAGES and err_code < 0:
#     287             # still raised if decoder fails to return anything
# --> 288             raise_oserror(err_code)
#     289
#     290         return Image.Image.load(self)
#
# /usr/local/lib/python3.9/dist-packages/PIL/ImageFile.py in raise_oserror(error)
#      70         msg = f"decoder error {error}"
#      71     msg += " when reading image file"
# ---> 72     raise OSError(msg)
#      73
#      74
#
# OSError: unrecognized data stream contents when reading image file

# %%
test = 0
if test == 1:
  str_test = 'test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + '2xto1x_' + str_test + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")

# %% [markdown]
# ### Running third configs: 8x to 1x direct

# %%
dir_hr = '../../Data/AID/AIDx1/'
dir_res = '../../Data/AID/Outputs/EDSRp8x-Bicubic_X8_L1loss_lr1e4_04182023/'

# %%
test = 0
if test == 1:
  str_test = 'test' 
  str_test2 = 'Test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  str_test2 = 'Valid' 
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + 'Images_' + str_test2 + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")

# %%
test = 1
if test == 1:
  str_test = 'test' 
  str_test2 = 'Test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  str_test2 = 'Valid' 
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + 'Images_' + str_test2 + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")

# %% [markdown]
# ### Running fourth configs - 4x to 1x direct

# %%
dir_hr = '../../Data/AID/AIDx1/'
dir_res = '../../Data/AID/Outputs/EDSRp4x-Bicubic_X4_L1loss_lr1e4_04172023/'

# %%
test = 0
if test == 1:
  str_test = 'test' 
  str_test2 = 'Test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  str_test2 = 'Valid' 
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + 'Images_' + str_test2 + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")

# %%
test = 1
if test == 1:
  str_test = 'test' 
  str_test2 = 'Test' 
  csv_file = csv_test
else:
  str_test = 'valid'  
  str_test2 = 'Valid' 
  csv_file = csv_valid

# %%
list_files = np.genfromtxt(csv_file,dtype='str')

# %%
# Set up the paths to the dataset directory and the output file
output_file = dir_res + str_test + '_result.csv'

# Initialize the LPIPS loss function
loss_fn_vgg = lpips.LPIPS(net='vgg')

# Iterate over all image pairs in the dataset directory and compute LPIPS, PSNR, and SSIM for each pair
with open(output_file, 'w') as f:
    for file in tqdm(list_files):
      ind = [m.start() for m in list(re.finditer(r'/',file))]

      img_HR = Image.open(file)
      file2 = dir_res + 'Images_' + str_test2 + file[ind[-1]:]
      img_SR = Image.open(file2)

      # Convert images to tensors
      img1_tensor = torch.tensor(np.array(img_HR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
      img2_tensor = torch.tensor(np.array(img_SR)).permute(2, 0, 1).unsqueeze(0).float() / 255.0

      # Compute LPIPS distance
      lpips_distance = loss_fn_vgg(img1_tensor, img2_tensor).item()

      # Compute PSNR
      img1_np = np.array(img_HR)
      img2_np = np.array(img_SR)
      psnr = peak_signal_noise_ratio(img1_np, img2_np)

      # Compute SSIM
      ssim_value = ssim(img1_np, img2_np, multichannel=True)

      # Write the results to the output file
      f.write(f"{file},{file2},{lpips_distance},{psnr},{ssim_value}\n")

# %%
img_HR
